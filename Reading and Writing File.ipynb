# %%
import pandas as pd

# %%
import os

# %%
pwd()
# Out:
# 'C:\\Users\\gurpreet.deol\\Desktop\\XChallenge App\\API_LOG_1\\More Logs\\APILog_'

# %%
data = pd.read_text(r"C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-16-api.log")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-6dce95ebdf77> in <module>
# ----> 1 data = pd.read_text(r"C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-16-api.log")
#
# AttributeError: module 'pandas' has no attribute 'read_text'

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
# ...

# %%
data = open(r"C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-16-api.log")

# %%
data
# Out:
# <_io.TextIOWrapper name='C:\\Users\\gurpreet.deol\\Desktop\\XChallenge App\\API_LOG_1\\More Logs\\APILog_\\2019-06-16-api.log' mode='r' encoding='cp1252'>

# %%
pd_data = pd.read_csv(r"C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-16-api.log", sep=r'\\t', engine='python')

# %%
pd_data
# Out:
#      2019-06-16 02:49:36.9267|INFO|Organo.Solutions.X4Ever.V1.API.Security.Helpers.NLogger|JSON
# 0                                           Method: GET
# 1     URL: https://mapp.oghq.ca/api/userpivot/authus...
# 2           Token: 0ffe002d-b7cd-404d-8c01-0a9c7b01a99a
# 3     Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
# 4                               Action : GetAuthUser_V3
# 5     Action Parameters : {"messageFormat":"JSON","m...
# 6     2019-06-16 02:49:37.4582|INFO|Organo.Solutions...
# 7                                           Method: GET
# 8            URL: https://mapp.oghq.ca/api/appmenus/get
# 9           Token: 0ffe002d-b7cd-404d-8c01-0a9c7b01a99a
# 10    Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
# 11                                   Action : GetByUser
# 12    Action Parameters : {"messageFormat":"JSON","m...
# 13    2019-06-16 02:49:37.6769|INFO|Organo.Solutions...
# 14                                          Method: GET
# ...

# %%
type(pd_data)
# Out:
# pandas.core.frame.DataFrame

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
api_list = ['2019-06-16-api.log',
'2019-06-17-api.log',
'2019-06-18-api.log',
'2019-06-19-api.log',
'2019-06-20-api.log',
'2019-06-21-api.log',
'2019-06-22-api.log',
'2019-06-23-api.log',
'2019-06-24-api.log',
'2019-06-25-api.log',
'2019-06-26-api.log',
'2019-06-27-api.log',
'2019-06-28-api.log',
'2019-06-29-api.log',
'2019-06-30-api.log',
'2019-07-01-api.log',
'2019-07-02-api.log',
'2019-07-03-api.log',
'2019-07-04-api.log',
'2019-07-05-api.log',
'2019-07-06-api.log',
'2019-07-07-api.log',
'2019-07-08-api.log']
pd_new_data = []

# %%
pd_new_data
# Out:
# []

# %%
for i in range(len(api_list)):
    print(r"C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\{0}".format(api_list[i]))
# Out:
# C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-16-api.log
# C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-17-api.log
# C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-18-api.log
# C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-19-api.log
# C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-20-api.log
# C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-21-api.log
# C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-22-api.log
# C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-23-api.log
# C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-24-api.log
# C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\2019-06-25-api.log
# ...

# %%
frames = []
frames.append(pd_data)
frames
# Out:
# [     2019-06-17 05:34:01.9982|INFO|Organo.Solutions.X4Ever.V1.API.Security.Helpers.NLogger|JSON
#  0                                           Method: GET
#  1     URL: https://mapp.oghq.ca/api/appinfo/get?plat...
#  2     Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
#  3                                          Action : Get
#  4     Action Parameters : {"messageFormat":"JSON","m...
#  5     2019-06-17 05:35:58.9201|INFO|Organo.Solutions...
#  6                                           Method: GET
#  7     URL: https://mapp.oghq.ca/api/appinfo/get?plat...
#  8     Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
#  9                                          Action : Get
#  10    Action Parameters : {"messageFormat":"JSON","m...
#  11    2019-06-17 05:36:06.4690|INFO|Organo.Solutions...
#  12                                         Method: POST
#  13    URL: https://mapp.oghq.ca/api/authenticatepivo...
#  14    Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
# ...

# %%
for i in range(len(api_list)):
    frames.append(pd.read_csv(r"C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\{0}".format(api_list[i]), sep=r'\\t', engine='python'))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-40-24e81e3ed10d> in <module>
#       1 for i in range(len(api_list)):
# ----> 2     frames.append(pd.read_csv(r"C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\{0}".format(api_list[i]), sep=r'\\t', engine='python'))
#       3
#
# ...

# %%
frames
# Out:
# [     2019-06-17 05:34:01.9982|INFO|Organo.Solutions.X4Ever.V1.API.Security.Helpers.NLogger|JSON
#  0                                           Method: GET
#  1     URL: https://mapp.oghq.ca/api/appinfo/get?plat...
#  2     Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
#  3                                          Action : Get
#  4     Action Parameters : {"messageFormat":"JSON","m...
#  5     2019-06-17 05:35:58.9201|INFO|Organo.Solutions...
#  6                                           Method: GET
#  7     URL: https://mapp.oghq.ca/api/appinfo/get?plat...
#  8     Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
#  9                                          Action : Get
#  10    Action Parameters : {"messageFormat":"JSON","m...
#  11    2019-06-17 05:36:06.4690|INFO|Organo.Solutions...
#  12                                         Method: POST
#  13    URL: https://mapp.oghq.ca/api/authenticatepivo...
#  14    Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
# ...

# %%
frames[1]
# Out:
#      2019-06-16 02:49:36.9267|INFO|Organo.Solutions.X4Ever.V1.API.Security.Helpers.NLogger|JSON
# 0                                           Method: GET
# 1     URL: https://mapp.oghq.ca/api/userpivot/authus...
# 2           Token: 0ffe002d-b7cd-404d-8c01-0a9c7b01a99a
# 3     Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
# 4                               Action : GetAuthUser_V3
# 5     Action Parameters : {"messageFormat":"JSON","m...
# 6     2019-06-16 02:49:37.4582|INFO|Organo.Solutions...
# 7                                           Method: GET
# 8            URL: https://mapp.oghq.ca/api/appmenus/get
# 9           Token: 0ffe002d-b7cd-404d-8c01-0a9c7b01a99a
# 10    Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
# 11                                   Action : GetByUser
# 12    Action Parameters : {"messageFormat":"JSON","m...
# 13    2019-06-16 02:49:37.6769|INFO|Organo.Solutions...
# 14                                          Method: GET
# ...

# %%
final_data = pd.concat(frames,sort=False)

# %%
final_data
# Out:
#      2019-06-17 05:34:01.9982|INFO|Organo.Solutions.X4Ever.V1.API.Security.Helpers.NLogger|JSON  \
# 0                                           Method: GET
# 1     URL: https://mapp.oghq.ca/api/appinfo/get?plat...
# 2     Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
# 3                                          Action : Get
# 4     Action Parameters : {"messageFormat":"JSON","m...
# 5     2019-06-17 05:35:58.9201|INFO|Organo.Solutions...
# 6                                           Method: GET
# 7     URL: https://mapp.oghq.ca/api/appinfo/get?plat...
# 8     Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
# 9                                          Action : Get
# 10    Action Parameters : {"messageFormat":"JSON","m...
# 11    2019-06-17 05:36:06.4690|INFO|Organo.Solutions...
# 12                                         Method: POST
# 13    URL: https://mapp.oghq.ca/api/authenticatepivo...
# 14    Controller : Organo.Solutions.X4Ever.V1.DAL.AP...
# ...

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
# ...

# %%
final_data.to_csv(r"C:\Users\gurpreet.deol\Desktop\XChallenge App\API_LOG_1\More Logs\APILog_\API_LOG_ALL.log", encoding='utf-8', index=False)
